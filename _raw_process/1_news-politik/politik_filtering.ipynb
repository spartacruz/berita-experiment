# %%
import json

with open("1_politik_cnn_index_results.json", "r", encoding="utf-8") as f:
    data = json.load(f)
    
# print(data)

# %%
# Extract all tags, using a set to automatically remove duplicates
unique_tags = set(item.get('tag') for item in data if item.get('tag'))
# Print the unique tags
for tag in unique_tags:
    print(tag)
# Out:
# VOX POP POLITIK
# WHAT THE FACT! POLITICS
# DPD AWARD 2025
# KOLOM
# HEAD TO HEAD
# ANALISIS
# HARI BHAYANGKARA KE-79
# THE BIG IDEA FORUM
# BREAKING NEWS
# PRIME PLUS
# GO MUDIK CNN INDONESIA
# VIDEO

# %%
# Filter out any items that have the tag "VIDEO"
filtered_data = [item for item in data if item.get('tag') != "VIDEO"]
print(f"Original count: {len(data)}")
print(f"Filtered count: {len(filtered_data)}")
# Out:
# Original count: 5000
# Filtered count: 4990

# %%
data = filtered_data

# %%
# Title begins with
prefixes = ("FOTO:", "VIDEO:", "INFOGRAFIS:")
# Filter OUT any items where the title begins with any of the prefixes
filtered_data = [
    item for item in data 
    if not item.get('title', '').startswith(prefixes)
]
print(f"Original count: {len(data)}")
print(f"Filtered count: {len(filtered_data)}")
# Out:
# Original count: 4990
# Filtered count: 4867

# %%
data = filtered_data

# %%
output_file = "1_politik_cnn_index_results_filtered.json"

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2, ensure_ascii=False)
print(f"Successfully saved {len(data)} items to {output_file}")
# Out:
# Successfully saved 4867 items to 1_politik_cnn_index_results_filtered.json
