# %%
import json

with open("4_olahraga_cnn_index_results.json", "r", encoding="utf-8") as f:
    data = json.load(f)
    
# print(data)

# %%
# Extract all tags, using a set to automatically remove duplicates
unique_tags = set(item.get('tag') for item in data if item.get('tag'))
# Print the unique tags
for tag in unique_tags:
    print(tag)
# Out:
# FIFA SERIES
# PIALA DUNIA
# PARADE JUARA BARCELONA
# MOTO3 PRANCIS 2026
# FINAL LIGA 2
# PROLIGA 2026
# PIALA AFF FUTSAL
# KOLOM
# BNP PARIBAS OPEN 2026
# WHAT THE FACT! SPORT
# MOTO3 AMERIKA 2026
# MOTO3 CATALUNYA
# FINAL LIGA CHAMPIONS
# JOGJA FINANCIAL FESTIVAL 2026
# PIALA AFF U-19 2026
# UBER CUP
# LAPORAN INTERAKTIF
# FIFA SERIES 2026
# PIALA DUNIA 2026
# PIALA AFF U-17 2026
# VIDEO
# FINAL FOUR PROLIGA 2026
# SINGAPORE OPEN 2026
# PIALA AFF FUTSAL 2026
# PIALA ASIA 2027
# KUALIFIKASI PIALA DUNIA 2026
# CARABAO CUP
# UFC 328
# LIGA CHAMPIONS ASIA
# OBITUARI
# PIALA AFF U-17
# ALL ENGLAND 2026
# THOMAS UBER CUP
# MOTOGP THAILAND 2026
# PIALA ASIA U-17 2026
# SUPER LEAGUE
# MOTOGP SPANYOL
# ANALISIS
# SAUDI PRO LEAGUE
# MOTO3 BRASIL
# PROLIGA
# PIALA AFF FUTSAL WANITA 2026
# SEJARAH PIALA DUNIA
# THOMAS CUP 2026
# BADMINTON ASIA CHAMPIONSHIP
# LIGA CHAMPIONS
# THOMAS CUP
# MOTOGP THAILAND

# %%
exclude_tags = {
    "WHAT THE FACT! SPORT",
    "LAPORAN INTERAKTIF",
    "VIDEO",
}
# Filter out any items where the tag is in the exclude_tags set
filtered_data = [item for item in data if item.get('tag') not in exclude_tags]
print(f"Original count: {len(data)}")
print(f"Filtered count: {len(filtered_data)}")
# Out:
# Original count: 5000
# Filtered count: 4959

# %%
data = filtered_data

# %%
# Title begins with
prefixes = ("FOTO:", "VIDEO:", "INFOGRAFIS:")
# Filter OUT any items where the title begins with any of the prefixes
filtered_data = [
    item for item in data 
    if not item.get('title', '').startswith(prefixes)
]
print(f"Original count: {len(data)}")
print(f"Filtered count: {len(filtered_data)}")
# Out:
# Original count: 4959
# Filtered count: 4725

# %%
data = filtered_data

# %%
output_file = "5_teknologi_cnn_index_results_filtered.json"

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2, ensure_ascii=False)
print(f"Successfully saved {len(data)} items to {output_file}")
# Out:
# Successfully saved 4725 items to 5_teknologi_cnn_index_results_filtered.json
